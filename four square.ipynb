# %% [markdown]
# # Foursquare API

# %% [markdown]
# ### import necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/yidwa/anaconda2
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     curl-7.62.0                |       ha441bb4_0         135 KB
#     conda-package-handling-1.6.0|   py27h01d97ff_0         1.4 MB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         143 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     libssh2-1.8.2              |       hcdc9a53_2         221 KB  conda-forge
#     python-2.7.3               |                5        10.0 MB
#     libcurl-7.62.0             |       h051b688_0         488 KB
#     cryptography-2.7           |   py27h212c5bf_0         568 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     readline-6.2               |                2         274 KB
#     openssl-1.1.1c             |       h01d97ff_0         1.9 MB  conda-forge
#     conda-4.7.12               |           py27_0         3.0 MB  conda-forge
#     pycurl-7.19.0              |           py27_1         189 KB
#     certifi-2019.9.11          |           py27_0         147 KB  conda-forge
#     tqdm-4.36.1                |             py_0          43 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        18.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     conda-package-handling: 1.6.0-py27h01d97ff_0    conda-forge
#     geographiclib:          1.50-py_0               conda-forge
#     geopy:                  1.20.0-py_0             conda-forge
#     tqdm:                   4.36.1-py_0             conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates:        2018.03.07-0                        --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:                2018.1.18-py27_0                    --> 2019.9.11-py27_0     conda-forge
#     conda:                  4.5.0-py27_0                        --> 4.7.12-py27_0        conda-forge
#     cryptography:           2.1.4-py27hdbc5e8f_0                --> 2.7-py27h212c5bf_0   conda-forge
#     curl:                   7.58.0-ha441bb4_0                   --> 7.62.0-ha441bb4_0
#     libcurl:                7.58.0-hf30b1f0_0                   --> 7.62.0-h051b688_0
#     libssh2:                1.8.0-h322a93b_4                    --> 1.8.2-hcdc9a53_2     conda-forge
#     openssl:                1.0.2o-h26aff7b_0                   --> 1.1.1c-h01d97ff_0    conda-forge
#
# The following packages will be DOWNGRADED:
#
#     pycurl:                 7.43.0.1-py27hdbc3d79_0             --> 7.19.0-py27_1
#     python:                 2.7.14-hde5916a_29                  --> 2.7.3-5
#     readline:               7.0-hc1231fa_4                      --> 6.2-2
#
#
# Downloading and Extracting Packages
# curl 7.62.0: ########################################################### | 100%
# conda-package-handling 1.6.0: ########################################## | 100%
# ca-certificates 2019.9.11: ############################################# | 100%
# geopy 1.20.0: ########################################################## | 100%
# libssh2 1.8.2: ######################################################### | 100%
# python 2.7.3: ########################################################## | 100%
# libcurl 7.62.0: ######################################################## | 100%
# cryptography 2.7: ###################################################### | 100%
# geographiclib 1.50: #################################################### | 100%
# readline 6.2: ########################################################## | 100%
# openssl 1.1.1c: ######################################################## | 100%
# conda 4.7.12: ########################################################## | 100%
# pycurl 7.19.0: ######################################################### | 100%
# certifi 2019.9.11: ##################################################### | 100%
# tqdm 4.36.1: ########################################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Vendor:  continuum
# Product: anaconda
# Message: trial mode expires in 30 days
# /Users/yidwa/anaconda2/lib/python2.7/site-packages/cryptography/hazmat/primitives/constant_time.py:26: CryptographyDeprecationWarning: Support for your Python version is deprecated. The next version of cryptography will remove support. Please upgrade to a release (2.7.7+) that supports hmac.compare_digest as soon as possible.
#   utils.PersistentlyDeprecated2018,
# Collecting package metadata (repodata.json): done
# Solving environment: /
# Warning: >10 possible package resolutions (only showing differing packages):
#   - defaults::mpfr-3.1.5-h711e7fd_2, https://repo.continuum.io/pkgs/main/osx-64/idna-2.6-py27hedea723_1.tar.bz2::idna-2.6-py27hedea723_1, https://repo.continuum.io/pkgs/main/osx-64/nltk-3.2.5-py27h2e86947_0.tar.bz2::nltk-3.2.5-py27h2e86947_0, https://repo.continuum.io/pkgs/main/osx-64/scandir-1.6-py27h97aa1ee_0.tar.bz2::scandir-1.6-py27h97aa1ee_0
#   - defaults::mpfr-3.1.5-h711e7fd_2, defaults::scandir-1.6-py27h97aa1ee_0, https://repo.continuum.io/pkgs/main/osx-64/idna-2.6-py27hedea723_1.tar.bz2::idna-2.6-py27hedea723_1, https://repo.continuum.io/pkgs/main/osx-64/nltk-3.2.5-py27h2e86947_0.tar.bz2::nltk-3.2.5-py27h2e86947_0
#   - defaults::mpfr-3.1.5-h711e7fd_2, defaults::nltk-3.2.5-py27h2e86947_0, https://repo.continuum.io/pkgs/main/osx-64/idna-2.6-py27hedea723_1.tar.bz2::idna-2.6-py27hedea723_1, https://repo.continuum.io/pkgs/main/osx-64/scandir-1.6-py27h97aa1ee_0.tar.bz2::scandir-1.6-py27h97aa1ee_0
#   - defaults::mpfr-3.1.5-h711e7fd_2, defaults::nltk-3.2.5-py27h2e86947_0, defaults::scandir-1.6-py27h97aa1ee_0, https://repo.continuum.io/pkgs/main/osx-64/idna-2.6-py27hedea723_1.tar.bz2::idna-2.6-py27hedea723_1
#   - defaults::idna-2.6-py27hedea723_1, defaults::mpfr-3.1.5-h711e7fd_2, defaults::nltk-3.2.5-py27h2e86947_0, https://repo.continuum.io/pkgs/main/osx-64/scandir-1.6-py27h97aa1ee_0.tar.bz2::scandir-1.6-py27h97aa1ee_0
#   - defaults::idna-2.6-py27hedea723_1, defaults::mpfr-3.1.5-h711e7fd_2, defaults::nltk-3.2.5-py27h2e86947_0, defaults::scandir-1.6-py27h97aa1ee_0
#   - defaults::idna-2.6-py27hedea723_1, defaults::mpfr-3.1.5-h711e7fd_2, https://repo.continuum.io/pkgs/main/osx-64/nltk-3.2.5-py27h2e86947_0.tar.bz2::nltk-3.2.5-py27h2e86947_0, https://repo.continuum.io/pkgs/main/osx-64/scandir-1.6-py27h97aa1ee_0.tar.bz2::scandir-1.6-py27h97aa1ee_0
#   - defaults::idna-2.6-py27hedea723_1, defaults::mpfr-3.1.5-h711e7fd_2, defaults::scandir-1.6-py27h97aa1ee_0, https://repo.continuum.io/pkgs/main/osx-64/nltk-3.2.5-py27h2e86947_0.tar.bz2::nltk-3.2.5-py27h2e86947_0
#   - defaults::idna-2.6-py27hedea723_1, https://repo.continuum.io/pkgs/main/osx-64/mpfr-3.1.5-h711e7fd_2.tar.bz2::mpfr-3.1.5-h711e7fd_2, https://repo.continuum.io/pkgs/main/osx-64/nltk-3.2.5-py27h2e86947_0.tar.bz2::nltk-3.2.5-py27h2e86947_0, https://repo.continuum.io/pkgs/main/osx-64/scandir-1.6-py27h97aa1ee_0.tar.bz2::scandir-1.6-py27h97aa1ee_0
#   - https://repo.continuum.io/pkgs/main/osx-64/idna-2.6-py27hedea723_1.tar.bz2::idna-2.6-py27hedea723_1, https://repo.continuum.io/pkgs/main/osx-64/mpfr-3.1.5-h711e7fd_2.tar.bz2::mpfr-3.1.5-h711e7fd_2, https://repo.continuum.io/pkgs/main/osx-64/nltk-3.2.5-py27h2e86947_0.tar.bz2::nltk-3.2.5-py27h2e86947_0, https://repo.continuum.io/pkgs/main/osx-64/scandir-1.6-py27h97aa1ee_0.tar.bz2::scandir-1.6-py27h97aa1ee_0
#   ... and othedone
#
# ## Package Plan ##
#
#   environment location: /Users/yidwa/anaconda2
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-5.1.0    |           py27_2           5 KB
#     altair-3.2.0               |           py27_0         743 KB  conda-forge
#     blas-1.0                   |              mkl           5 KB
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         852 KB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-5.1.0-py27_2
#   altair             conda-forge/osx-64::altair-3.2.0-py27_0
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   branca             conda-forge/noarch::branca-0.3.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be DOWNGRADED:
#
#   alabaster                                                 -->
#   anaconda-navigator                                        -->
#   appnope                                                   -->
#   astropy                                                   -->
#   attrs                                                     -->
#   babel                                                     -->
#   backports                                                 -->
#   backports.functoo~                                        -->
#   backports.shutil_~                                        -->
#   backports_abc                                             -->
#   beautifulsoup4                                            -->
#   bitarray                                                  -->
#   bkcharts                                                  -->
#   blaze                                                     -->
#   bleach                                                    -->
#   boto                                                      -->
#   bottleneck                                                -->
#   cdecimal                                                  -->
#   chardet                                                   -->
#   click                                                     -->
#   conda-build                                               -->
#   conda-env                                                 -->
#   configparser                                              -->
#   cycler                                                    -->
#   cython                                                    -->
#   dask                                                      -->
#   dbus                                                      -->
#   decorator                                                 -->
#   docutils                                                  -->
#   entrypoints                                               -->
#   fastcache                                                 -->
#   filelock                                                  -->
#   flask                                                     -->
#   flask-cors                                                -->
#   freetype                                                  -->
#   gettext                                                   -->
#   glob2                                                     -->
#   gmp                                                       -->
#   gmpy2                                                     -->
#   greenlet                                                  -->
#   h5py                                                      -->
#   hdf5                                                      -->
#   imageio                                                   -->
#   intel-openmp                                              -->
#   ipaddress                                                 -->
#   ipykernel                                                 -->
#   isort                                                     -->
#   jdcal                                                     -->
#   jedi                                                      -->
#   jinja2                                                    -->
#   jpeg                                                      -->
#   jupyter_client                                            -->
#   jupyterlab_launch~                                        -->
#   lazy-object-proxy                                         -->
#   libcxx                                                    -->
#   libedit                                                   -->
#   libffi                                                    -->
#   libiconv                                                  -->
#   libsodium                                                 -->
#   libtiff                                                   -->
#   llvmlite                                                  -->
#   lxml                                                      -->
#   lzo                                                       -->
#   markupsafe                                                -->
#   matplotlib                                                -->
#   mccabe                                                    -->
#   mkl-service                                               -->
#   mpfr                                                      -->
#   nbformat                                                  -->
#   ncurses                                                   -->
#   notebook                                                  -->
#   numba                                                     -->
#   numexpr                                                   -->
#   openpyxl                                                  -->
#   packaging                                                 -->
#   pandas                                                    -->
#   pandoc                                                    -->
#   pandocfilters                                             -->
#   parso                                                     -->
#   partd                                                     -->
#   patsy                                                     -->
#   pcre                                                      -->
#   pep8                                                      -->
#   pexpect                                                   -->
#   pickleshare                                               -->
#   pillow                                                    -->
#   pkginfo                                                   -->
#   ply                                                       -->
#   ptyprocess                                                -->
#   pyaudio                                                   -->
#   pycodestyle                                               -->
#   pycrypto                                                  -->
#   pyflakes                                                  -->
#   pygments                                                  -->
#   pyodbc                                                    -->
#   pyopenssl                                                 -->
#   pysocks                                                   -->
#   pytables                                                  -->
#   pyyaml                                                    -->
#   qt                                                        -->
#   qtawesome                                                 -->
#   qtconsole                                                 -->
#   rope                                                      -->
#   ruamel_yaml                                               -->
#   scikit-learn                                              -->
#   setuptools                                                -->
#   simplegeneric                                             -->
#   spyder                                                    -->
#   sqlalchemy                                                -->
#   sqlite                                                    -->
#   subprocess32                                              -->
#   toolz                                                     -->
#   tornado                                                   -->
#   traitlets                                                 -->
#   unicodecsv                                                -->
#   wcwidth                                                   -->
#   wheel                                                     -->
#   widgetsnbextension                                        -->
#   wrapt                                                     -->
#   xlrd                                                      -->
#   xlwings                                                   -->
#   xlwt                                                      -->
#   xz                                                        -->
#   yaml                                                      -->
#   zlib                                                      -->
#
#
#
# Downloading and Extracting Packages
# blas-1.0             | 5 KB      | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# _anaconda_depends-5. | 5 KB      | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-3.2.0         | 743 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# ### define foursquare credentials

# %%
CLIENT_ID = 'DIHBSCAXS0A3HJJFKH14HTPH0MXS0CVDXCPBV5C1KFZ4QGHK' # your Foursquare ID
CLIENT_SECRET = 'HJCAN3I3D0ZG4EY4ULIPGZ2EWSAK2STHZ5PDP1PN2ZIB5YSE' # your Foursquare Secret
VERSION = '20191004'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DIHBSCAXS0A3HJJFKH14HTPH0MXS0CVDXCPBV5C1KFZ4QGHK
# CLIENT_SECRET:HJCAN3I3D0ZG4EY4ULIPGZ2EWSAK2STHZ5PDP1PN2ZIB5YSE
